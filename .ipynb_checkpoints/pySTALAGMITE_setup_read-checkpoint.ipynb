# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pySTALAGMITE</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);"><b style=color:red;>STALAGMITE</b> modelling</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pySTALAGMITE.png"></td>
# </tr>
# </table>
#
# ----
# # `pySTALAGMITE`
#
# pySTALAGMITE, a program package prediction the shape of a stalagmite from pre-defined climate conditions.

# %%
import numpy as np
import libSTALAGMITE

# %% [markdown]
# ----
# # Read input parameter for `pySTALAGMITE`
#
# In this notebook, we introduce the functions **reading input data** for a stalagmite run.
#
# ----
# ## `readParameter2D()`
#
# First, we read in the input file `STALAGMITE_parameter.in`.
# We use the example from the `work` directory:
#
# ~~~
# #=======================================================
# #=== geometry ==========================================
# #=======================================================
#   0.40    801           # sidex [m], nx
#   0.01                  # init_height [m]
# #=======================================================
# #=== define time series ================================
# #=======================================================
#      10                 # timeStep [a]
#    1000                 # timeWrite  [a]
# #=======================================================
# #=== climate ===========================================
# #=======================================================
#     10.     10.         # TSoilmin,TSoilmax [C]
#  30000.  30000.         # PSoilmin,PSoilmax [ppm]
#    400.    400.         # PAtmmin,PAtmmax [ppm]
#     10.     10.         # TCavemin,TCavemax [C]
#    400.    400.         # PCavemin,PCavemax [ppm]
#    100.    100.         # dropCavemin,dropCavemax [s]
# ~~~
#
# This file contains:
# ### geometry:
# - `sidex`: [m] half width of model
# - `nx`: discretisation
#
# ### time series:
#
# - `timeStep`: [a] time step of model
# - `timeWrite`: [a] write time for model output
#
# ### climate: (will be used by time series for interpolation)
#
# - `TSoilmin,TSoilmax`: [C] min/max values for soil temperature
# - `PSoilmin,PSoilmax`: [ppm] min/max values for soil CO2
# - `PAtmmin,PAtmmax`: [ppm] min/max values for atmospheric CO2
# - `TCavemin,TCavemax`: [C] min/max values for cave temperature
# - `PCavemin,PCavemax`: [ppm] min/max values for cave CO2
# - `dropCavemin,dropCavemax`: [s] min/max values for cave drip interval
#
# Next, we check the function info with `help`, then we run the function on example input.

# %%
help(libSTALAGMITE.readParameter2D)
# Out:
# Help on function readParameter2D in module libSTALAGMITE:
#
# readParameter2D(infile='STALAGMITE_parameter.in', path='work/', control=False)
#     ! read STALAGMITE parameter file
#     ! input:
#     !  (from file infile)
#     ! output:
#     !  xmin,xmax,nx         - min/max for x coordinate [m], discretisation
#     !  whichtime            - flag for time units used
#     !  time_start,time_end  - start/end point for time scale [s]
#     !  time_step            - time step [s]
#     !  time_scale           - scaling coefficient for user time scale
#     ! use:
#     !  sidex,nx,init_height,timeStep,timeWrite,TSoilmin,TSoilmax,PSoilmin,PSoilmax,
#         PAtmmin,PAtmmax,TCavemin,TCavemax,PCavemin,PCavemax,dropCavemin,dropCavemax = libSTALAGMITE.readParameter2D()
#     ! note:
#     !  file structure given!
#     !  uses readline(),variables come in as string,
#     !  must be separated and converted ...

# %%
libSTALAGMITE.readParameter2D(control=True)
# Out:
# == STALAGMITE ==
#                          path:                work/
#                  sidex [m],nx:       0.40        801
#               init_height [m]:       0.01
#        timestep,timewrite [a]:      10.00      1000.00
#         TSoilmin,TSoilmax [C]:      10.00        10.00
#       PSoilmin,PSoilmax [ppm]:   30000.00     30000.00
#         PAtmmin,PAtmmax [ppm]:     400.00       400.00
#         TCavemin,TCavemax [C]:      10.00        10.00
#       PCavemin,PCavemax [ppm]:     400.00       400.00
#   dropCavemin,dropCavemax [s]:     100.00       100.00
# [0.4,
#  801,
#  0.01,
#  10.0,
#  1000.0,
#  10.0,
#  10.0,
#  30000.0,
#  30000.0,
#  400.0,
#  400.0,
#  10.0,
#  10.0,
#  400.0,
#  400.0,
#  100.0,
#  100.0]

# %% [markdown]
# ----
# ## `readTimeline2D()`
#
# Second, we read in the input file `STALAGMITE_timeline.in`.
# We use the example from the `work` directory:
#
# ~~~
# ! timeline and glacial index (0-interglacial; 1-glacial)
# ! time BP [yr]     TSoil [C]
#       -10000.0         10.00
#           00.0         10.00
# ~~~

# %%
help(libSTALAGMITE.readTimeline2D)
# Out:
# Help on function readTimeline2D in module libSTALAGMITE:
#
# readTimeline2D(infile='STALAGMITE_timeline.in', path='work/', control=False)
#     ! read STALAGMITE timeline file
#     ! input:
#     !  (from file infile)
#     ! output:
#     !  timeStart,timeEnd   - start/end point for time scale [s]
#     ! use:
#     !  timeStart,timeEnd,rawTimeline = libSTALAGMITE.readTimeline2D()
#     ! note:
#     !  file structure given!
#     !  uses loadtxt(), with 2 lines skipped!

# %%
libSTALAGMITE.readTimeline2D(control=True)
# Out:
#         timeStart,timeEnd [a]:  -10000.00         0.00
# (-10000.0,
#  0.0,
#  array([[-10000.,     10.],
#         [     0.,     10.]]))

# %% [markdown]
# ----
