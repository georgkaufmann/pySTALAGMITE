# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pySTALAGMITE</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);"><b style=color:red;>STALAGMITE</b> modelling</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pySTALAGMITE.png"></td>
# </tr>
# </table>
#
# ----
# # `pySTALAGMITE`
#
# pySTALAGMITE, a program package prediction the shape of a stalagmite from pre-defined climate conditions.

# %%
import numpy as np
import libSTALAGMITE

# %% [markdown]
# ----
# # Create grid for `pySTALAGMITE`
#
# In this notebook, we introduce the functions **creating the numerical grid** for a stalagmite run.
#
# ----
# ## `createGridD()`
#
# This function creates the 2D grid of the current stalagmite surface.
#
# It reads the geometry (`sidex`,`nx`) and the central height `init_height` of the initial surface.
#
# It then creates the horizontal grid points `x`  as 1D array,
# and the vertical extension as grid points `y`, with a linear function from `init_height` in the
# center towards zeros outside.

# %%
help(libSTALAGMITE.createGrid2D)
# Out:
# Help on function createGrid2D in module libSTALAGMITE:
#
# createGrid2D(sidex, nx, init_height=0, plot=False)
#     ! define initial geometry, shape as linear ramp
#     ! input:
#     !  sidex [m]  : length of model domain
#     !  nx         : steps
#     !  init_height: initial height at center (default: 0.)
#     !  plot       : plot flag (default: False)
#     ! output:
#     !  x,y [m]    : x- and y-coordinates
#     !  dx [m]     : discretisation
#     ! use:
#     !  x,y,dx = libSTALAGMITE.createGrid2D(sidex,nx,init_height)

# %%
x,y,dx = libSTALAGMITE.createGrid2D(sidex=0.4,nx=21,init_height=0.1)

# %% [markdown]
# ----
# ## `refineGridD()`
#
# The function `refineGridD()` is used in insert a new point along the x-axis between points. 0 and 1.

# %%
help(libSTALAGMITE.refineGrid2D)
# Out:
# Help on function refineGrid2D in module libSTALAGMITE:
#
# refineGrid2D(x, y)
#     ! function used to insert a grid point
#     ! next to the y-xis, when the grid is stretched too much
#     ! input:
#     !  x,y [m]     : x- and y-coordinates
#     ! output:
#     !  x,y [m]     : new x- and y-coordinates
#     ! use:
#     !  x,y = libSTALAGMITE.refineGrid2D(x,y)

# %%
print('old grid\n',x,y)
x,y = libSTALAGMITE.refineGrid2D(x,y)
print('refined grid\n',x,y)
# Out:
# old grid
#  [0.   0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2  0.22 0.24 0.26
#  0.28 0.3  0.32 0.34 0.36 0.38 0.4 ] [0.1   0.095 0.09  0.085 0.08  0.075 0.07  0.065 0.06  0.055 0.05  0.045
#  0.04  0.035 0.03  0.025 0.02  0.015 0.01  0.005 0.   ]
# refined grid
#  [0.   0.01 0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2  0.22 0.24
#  0.26 0.28 0.3  0.32 0.34 0.36 0.38] [0.1    0.0975 0.095  0.09   0.085  0.08   0.075  0.07   0.065  0.06
#  0.055  0.05   0.045  0.04   0.035  0.03   0.025  0.02   0.015  0.01
#  0.005 ]

# %% [markdown]
# ----
